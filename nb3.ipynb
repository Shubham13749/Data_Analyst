# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as slt
import seaborn as sns

# %%
df = pd.read_csv('./Top2000CompaniesGlobally.csv')
df.head(10)
# Out:
#    Global Rank                     Company  Sales ($billion)  \
# 0            1                        ICBC             134.8
# 1            2     China Construction Bank             113.1
# 2            3              JPMorgan Chase             108.2
# 3            4            General Electric             147.4
# 4            5                 Exxon Mobil             420.7
# 5            6               HSBC Holdings             104.9
# 6            7           Royal Dutch Shell             467.2
# 7            8  Agricultural Bank of China             103.0
# 8            9                  PetroChina             308.9
# 9            9          Berkshire Hathaway             162.5
#
#    Profits ($billion)  Assets ($billion)  Market Value ($billion)  \
# 0                37.8             2813.5                    237.3
# 1                30.6             2241.0                    202.0
# 2                21.3             2359.1                    191.4
# ...

# %%
df.isnull().sum()
# Out:
# Global Rank                0
# Company                    0
# Sales ($billion)           0
# Profits ($billion)         0
# Assets ($billion)          0
# Market Value ($billion)    0
# Country                    0
# Continent                  0
# Latitude                   0
# Longitude                  0
# dtype: int64

# %%
df.shape
# Out:
# (1924, 10)

# %%
df.describe()
# Out:
#        Global Rank  Sales ($billion)  Profits ($billion)  Assets ($billion)  \
# count  1924.000000       1924.000000         1924.000000        1924.000000
# mean    997.232848         19.265904            1.226040          79.507796
# std     575.502781         34.683911            3.413831         261.098775
# min       1.000000          0.000000          -24.500000           1.000000
# 25%     500.750000          4.100000            0.300000           9.675000
# 50%     997.500000          9.000000            0.600000          19.250000
# 75%    1494.250000         18.425000            1.200000          45.800000
# max    1999.000000        469.200000           44.900000        3226.200000
#
#        Market Value ($billion)     Latitude    Longitude
# count              1924.000000  1924.000000  1924.000000
# mean                 19.558160    34.618747    15.455664
# std                  32.957023    18.259499    92.639655
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1924 entries, 0 to 1923
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Global Rank              1924 non-null   int64
#  1   Company                  1924 non-null   object
#  2   Sales ($billion)         1924 non-null   float64
#  3   Profits ($billion)       1924 non-null   float64
#  4   Assets ($billion)        1924 non-null   float64
#  5   Market Value ($billion)  1924 non-null   float64
#  6   Country                  1924 non-null   object
#  7   Continent                1924 non-null   object
#  8   Latitude                 1924 non-null   float64
#  9   Longitude                1924 non-null   float64
# dtypes: float64(6), int64(1), object(3)
# memory usage: 150.4+ KB

# %%
df.columns
# Out:
# Index(['Global Rank', 'Company', 'Sales ($billion)', 'Profits ($billion)',
#        'Assets ($billion)', 'Market Value ($billion)', 'Country', 'Continent',
#        'Latitude', 'Longitude'],
#       dtype='object')

# %%
tdf=df.drop(columns=['Latitude','Longitude'], axis=1)
tdf.head(20)
# Out:
#     Global Rank                     Company  Sales ($billion)  \
# 0             1                        ICBC             134.8
# 1             2     China Construction Bank             113.1
# 2             3              JPMorgan Chase             108.2
# 3             4            General Electric             147.4
# 4             5                 Exxon Mobil             420.7
# 5             6               HSBC Holdings             104.9
# 6             7           Royal Dutch Shell             467.2
# 7             8  Agricultural Bank of China             103.0
# 8             9                  PetroChina             308.9
# 9             9          Berkshire Hathaway             162.5
# 10           11               Bank of China              98.1
# 11           12                 Wells Fargo              91.2
# 12           13                     Chevron             222.6
# 13           14            Volkswagen Group             254.0
# ...

# %%
tdf =df.loc[df['Country']=='China']
tdf.head(20)
# Out:
#      Global Rank                      Company  Sales ($billion)  \
# 0              1                         ICBC             134.8
# 1              2      China Construction Bank             113.1
# 7              8   Agricultural Bank of China             103.0
# 8              9                   PetroChina             308.9
# 10            11                Bank of China              98.1
# 25            26      Sinopec-China Petroleum             411.7
# 52            54       Bank of Communications              43.5
# 79            83      Ping An Insurance Group              51.1
# 96           101         China Merchants Bank              28.4
# 101          106         China Life Insurance              63.2
# 102          107       China Minsheng Banking              27.9
# 110          115         China Shenhua Energy              39.7
# 120          125  Shanghai Pudong Development              25.4
# 122          128             China Citic Bank              24.4
# ...

# %%
tdf= df.groupby(['Company'])['Market Value ($billion)'].sum()
tdf.head(20)
# Out:
# Company
# 3M               73.4
# 77 Bank           2.0
# A2A               1.9
# ADT              11.5
# AES               9.3
# AGCO              5.3
# AGL Energy        9.5
# AIA Group        53.5
# ALFA             12.7
# AMEC              4.8
# AMP              16.0
# AMR               1.3
# ANZ              81.2
# AOL               2.6
# ARM Holdings     19.6
# ASML Holding     28.9
# AT&T            200.1
# AU Optronics      3.8
# AXA Group        45.3
# Aareal Bank       1.4
# Name: Market Value ($billion), dtype: float64
